# %%
from PIL import Image, ImageFilter
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
path = "./bazy/kostka_raw/"

# %%
file_names = os.listdir(path)

# %%
images = []
images_gray = []
for file in file_names:
    image = Image.open(path+file)
   # image = image.filter(UnsharpMask(radius=2, percent=150, threshold=3))
    np_image = np.asarray(image)
    images.append(np_image)
    
    image_gray = image.convert('L')
    
    np_image_gray = np.asarray(image_gray)
    images_gray.append(np_image_gray)

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

# %%
index = 45

# %%
#plt.imshow(images[index])

# %%
plt.imshow(images_gray[index], cmap=plt.get_cmap('gray'), vmin=0, vmax=255)
#plt.show()

# %%
file = file_names[5]

# %%
imagex = Image.open(path+file)
imagex.show()
imagex = imagex.filter(ImageFilter.UnsharpMask(radius=2, percent=150, threshold=1))
imagex_gray = imagex.convert('L')
imagex.show()
imagex_gray.show()
