# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import Image

# %%
base = "./bazy/"
class_path = "kostka_raw/"

# %%
#changing all directory from png to jpg
file_list = os.listdir(base+class_path)
file_list
# Out:
# ['kostka_0_0.jpg',
#  'kostka_0_1.jpg',
#  'kostka_0_2.jpg',
#  'kostka_0_3.jpg',
#  'kostka_10_0.jpg',
#  'kostka_10_1.jpg',
#  'kostka_10_2.jpg',
#  'kostka_10_3.jpg',
#  'kostka_11_0.jpg',
#  'kostka_11_1.jpg',
#  'kostka_11_2.jpg',
#  'kostka_11_3.jpg',
#  'kostka_12_0.jpg',
#  'kostka_12_1.jpg',
#  'kostka_12_2.jpg',
#  'kostka_12_3.jpg',
#  'kostka_13_0.jpg',
#  'kostka_13_1.jpg',
#  'kostka_13_2.jpg',
#  'kostka_13_3.jpg',
#  'kostka_14_0.jpg',
#  'kostka_14_1.jpg',
#  'kostka_14_2.jpg',
#  'kostka_14_3.jpg',
#  'kostka_15_0.jpg',
#  'kostka_15_1.jpg',
#  'kostka_15_2.jpg',
#  'kostka_15_3.jpg',
#  'kostka_16_0.jpg',
#  'kostka_16_1.jpg',
#  'kostka_16_2.jpg',
#  'kostka_16_3.jpg',
#  'kostka_17_0.jpg',
#  'kostka_17_1.jpg',
#  'kostka_17_2.jpg',
#  'kostka_17_3.jpg',
#  'kostka_18_0.jpg',
#  'kostka_18_1.jpg',
#  'kostka_18_2.jpg',
#  'kostka_18_3.jpg',
#  'kostka_19_0.jpg',
#  'kostka_19_1.jpg',
#  'kostka_19_2.jpg',
#  'kostka_19_3.jpg',
#  'kostka_1_0.jpg',
# ...

# %%
path_good = "Kostka/"

# %%
os.makedirs(base+path_good)

# %%
i = 0
for file in file_list:
    newfilename = str(i)+".png"
    i=i+1
    image = Image.open(base+class_path+file)
    image = image.convert('L')
    new_image = image.resize((300,300))
    new_image.save(base+path_good+newfilename)
