# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import Image
import shutil

# %%
#https://stackoverflow.com/questions/53074712/how-to-split-folder-of-images-into-test-training-validation-sets-with-stratified
#train 60%
#validation 20%
#test 20%
#250 images for category, but we start splitting from 200 into train and validation so ratio is (75%/25%)
path = "./asfalt/0.0"

# %%
core_path = "./baza"
class1 = "/Asfalt/"
class2 = "/Kostka/"
class3 = "/Utwardzona/"
class4 = "/Polna/"

# %%
file_names = os.listdir(core_path+class1)
file_names
# Out:
# ['0.png',
#  '1.png',
#  '10.png',
#  '100.png',
#  '101.png',
#  '102.png',
#  '103.png',
#  '104.png',
#  '105.png',
#  '106.png',
#  '107.png',
#  '108.png',
#  '109.png',
#  '11.png',
#  '110.png',
#  '111.png',
#  '112.png',
#  '113.png',
#  '114.png',
#  '115.png',
#  '116.png',
#  '117.png',
#  '118.png',
#  '119.png',
#  '12.png',
#  '120.png',
#  '121.png',
#  '122.png',
#  '123.png',
#  '124.png',
#  '125.png',
#  '126.png',
#  '127.png',
#  '128.png',
#  '129.png',
#  '13.png',
#  '130.png',
#  '131.png',
#  '132.png',
#  '133.png',
#  '134.png',
#  '135.png',
#  '136.png',
#  '137.png',
#  '138.png',
#  '139.png',
#  '14.png',
#  '140.png',
#  '141.png',
#  '142.png',
#  '143.png',
#  '144.png',
#  '145.png',
#  '146.png',
#  '147.png',
#  '148.png',
#  '149.png',
#  '15.png',
#  '150.png',
#  '151.png',
#  '152.png',
#  '153.png',
#  '154.png',
#  '155.png',
#  '156.png',
#  '157.png',
#  '158.png',
#  '159.png',
#  '16.png',
#  '160.png',
#  '161.png',
#  '162.png',
#  '163.png',
#  '164.png',
#  '165.png',
#  '166.png',
#  '167.png',
#  '168.png',
#  '169.png',
#  '17.png',
#  '170.png',
#  '171.png',
#  '172.png',
#  '173.png',
#  '174.png',
#  '175.png',
#  '176.png',
#  '177.png',
#  '178.png',
#  '179.png',
#  '18.png',
#  '180.png',
#  '181.png',
#  '182.png',
#  '183.png',
#  '184.png',
#  '185.png',
#  '186.png',
#  '187.png',
#  '188.png',
#  '189.png',
#  '19.png',
#  '190.png',
#  '191.png',
#  '192.png',
#  '193.png',
#  '194.png',
#  '195.png',
#  '196.png',
#  '197.png',
#  '198.png',
#  '199.png',
#  '2.png',
#  '20.png',
#  '200.png',
#  '201.png',
#  '202.png',
#  '203.png',
#  '204.png',
#  '205.png',
#  '206.png',
#  '207.png',
#  '208.png',
#  '209.png',
#  '21.png',
#  '22.png',
#  '23.png',
#  '24.png',
#  '25.png',
#  '26.png',
#  '27.png',
#  '28.png',
#  '29.png',
#  '3.png',
#  '30.png',
#  '31.png',
#  '32.png',
#  '33.png',
#  '34.png',
#  '35.png',
#  '36.png',
#  '37.png',
#  '38.png',
#  '39.png',
#  '4.png',
#  '40.png',
#  '41.png',
#  '42.png',
#  '43.png',
#  '44.png',
#  '45.png',
#  '46.png',
#  '47.png',
#  '48.png',
#  '49.png',
#  '5.png',
#  '50.png',
#  '51.png',
#  '52.png',
#  '53.png',
#  '54.png',
#  '55.png',
#  '56.png',
#  '57.png',
#  '58.png',
#  '59.png',
#  '6.png',
#  '60.png',
#  '61.png',
#  '62.png',
#  '63.png',
#  '64.png',
#  '65.png',
#  '66.png',
#  '67.png',
#  '68.png',
#  '69.png',
#  '7.png',
#  '70.png',
#  '71.png',
#  '72.png',
#  '73.png',
#  '74.png',
#  '75.png',
#  '76.png',
#  '77.png',
#  '78.png',
#  '79.png',
#  '8.png',
#  '80.png',
#  '81.png',
#  '82.png',
#  '83.png',
#  '84.png',
#  '85.png',
#  '86.png',
#  '87.png',
#  '88.png',
#  '89.png',
#  '9.png',
#  '90.png',
#  '91.png',
#  '92.png',
#  '93.png',
#  '94.png',
#  '95.png',
#  '96.png',
#  '97.png',
#  '98.png',
#  '99.png']

# %%
os.makedirs(core_path +'/train' + class1)
os.makedirs(core_path +'/train' + class2)
os.makedirs(core_path +'/train' + class3)
os.makedirs(core_path +'/train' + class4)

os.makedirs(core_path +'/val' + class1)
os.makedirs(core_path +'/val' + class2)
os.makedirs(core_path +'/val' + class3)
os.makedirs(core_path +'/val' + class4)

# %%
current_class = class3
src = core_path + current_class
src
# Out:
# './baza/Utwardzona/'

# %%
file_names_all = os.listdir(src)
np.random.shuffle(file_names_all)
file_names_train, file_names_val = np.split(np.array(file_names_all),
                                                          [int(len(file_names_all)*0.75)])

# %%
print('Total images: ', len(file_names_all))
print('Training: ', len(file_names_train))
print('Validation: ', len(file_names_val))
# Out:
# Total images:  223
# Training:  167
# Validation:  56

# %%
#copy
for name in file_names_train:
    shutil.copy(src+"/"+name, core_path+"/train"+current_class)

for name in file_names_val:
    shutil.copy(src+"/"+name, core_path+"/val"+current_class)
